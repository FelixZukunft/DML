# %% [markdown]
# # EDA — DML Scholarship Dataset
# Exploratory analysis only. No modelling here.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sys; sys.path.insert(0, '..')

from src.data_pipeline import load_raw, clean
df_raw = load_raw()
df = clean(df_raw)
df.shape

# %%
df.describe()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
df.hist(ax=axes[0], bins=30)
sns.heatmap(df.corr(), ax=axes[1], cmap='coolwarm', center=0)
plt.tight_layout()
